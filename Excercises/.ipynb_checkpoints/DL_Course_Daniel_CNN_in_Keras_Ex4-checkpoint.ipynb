# %% [markdown]
# <h1> Intro to Convolutional Neural Networks (CNNs) - Keras </h1>
# <br>
# This excercise will present you how to interact with Keras API and build CNNs using Keras

# %% [markdown]
# <h3> Relevant Imports </h3>

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
# Out:
# 2022-07-08 14:24:22.404590: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-08 14:24:22.404613: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# <h3> Data Preprocessing </h3>
# A word about the data - This dataset is called MNIST. <br>
# This is a dataset of 60,000 28x28 grayscale images of the 10 digits, along with a test set of 10,000 images. <br>More info can be found at the
#
# [MNIST homepage](http://yann.lecun.com/exdb/mnist/)

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
# Let's illustrate the data and see what it actually contains

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The MNIST labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# <h3> Model Creation </h3>

# %%
## TODO: Using the Sequential API, create the below architecture
# 28x28x1 -> Conv2d (28 filters), filter size = 3 -> ReLU -> MaxPool (2x2) -> Conv2d (64 filters) -> relu -> MaxPool (2x2) -> Conv2d (64 filters) -> relu
# Out:
# 2022-07-08 14:24:28.940381: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-08 14:24:28.940414: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-08 14:24:28.940440: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (daniel-lap): /proc/driver/nvidia/version does not exist
# 2022-07-08 14:24:28.940750: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## TODO: On top of that network, make sure to add a:
# 1. Flatten Network
# 2. Dense Network which has 64 neurons, plus a Relu activation on top of it
# 3. Dense Network with 10 neurons (which will be relevant for the 10 classes within MNIST

# %%
## TODO: Print model summary
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Let's compile the model, don't touch the below

num_epochs=10
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=num_epochs, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.5692 - accuracy: 0.8006 - val_loss: 0.8582 - val_accuracy: 0.7170
# Epoch 2/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.5377 - accuracy: 0.8111 - val_loss: 0.8782 - val_accuracy: 0.7168
# Epoch 3/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.5135 - accuracy: 0.8187 - val_loss: 0.8883 - val_accuracy: 0.7243
# Epoch 4/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.4839 - accuracy: 0.8292 - val_loss: 0.8844 - val_accuracy: 0.7279
# Epoch 5/10
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.4581 - accuracy: 0.8375 - val_loss: 0.9715 - val_accuracy: 0.7025
# Epoch 6/10
# 1563/1563 [==============================] - 22s 14ms/step - loss: 0.4312 - accuracy: 0.8466 - val_loss: 0.9608 - val_accuracy: 0.7133
# Epoch 7/10
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.4105 - accuracy: 0.8542 - val_loss: 1.0422 - val_accuracy: 0.6982
# Epoch 8/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.3864 - accuracy: 0.8623 - val_loss: 1.0794 - val_accuracy: 0.7069
# Epoch 9/10
# 1563/1563 [==============================] - 21s 14ms/step - loss: 0.3687 - accuracy: 0.8685 - val_loss: 1.0808 - val_accuracy: 0.7104
# Epoch 10/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.3505 - accuracy: 0.8749 - val_loss: 1.0567 - val_accuracy: 0.7176

# %%
# Let's plot how the model trained, don't touch the below
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 1.0567 - accuracy: 0.7176

# %%
# print test accuracy
print(test_acc)
# Out:
# 0.7175999879837036
